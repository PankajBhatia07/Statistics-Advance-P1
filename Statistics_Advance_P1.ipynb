# %% [markdown]
# ## **Q1.What is a random variable in probability theory?**

# %% [markdown]
# A random variable in probability theory is a function that assigns a numerical value to each outcome in a sample space of a random experiment. It provides a way to quantify uncertainty by mapping outcomes to real numbers.
#
# **Types of Random Variables:**
#
# **1.Discrete Random Variable** – Takes a finite or countably infinite set of values (e.g., number of heads in coin tosses).
#
# **2.Continuous Random Variable** – Takes values from a continuous range (e.g., height of people, time taken for an event)
#
# **Mathematical Definition:**
#
# A random variable
# 𝑋
# X is a function:
#
# 𝑋
# :
# Ω
# →
# 𝑅
# X:Ω→R
# where
# Ω
# Ω is the sample space of a probability experiment, and
# 𝑋
# (
# 𝜔
# )
# X(ω) maps each outcome
# 𝜔
# ω to a real number.
#
# A random variable is characterized by its probability distribution, which describes the likelihood of different values it can take.

# %% [markdown]
# ## **Q2.What are the types of random variables?**

# %% [markdown]
# There are two main types of random variables in probability theory:

# %% [markdown]
# **1.Discrete Random Variable**
#
# A discrete random variable takes a finite or countably infinite set of values.
#
# It is associated with discrete probability distributions (e.g., Binomial, Poisson).
#
# The probability of each value is given by a Probability Mass Function (PMF).
#
# * **Examples:**
#  * Number of heads in 5 coin flips.
#  * Number of customers arriving at a store in an hour.
#  * Number of defective items in a batch.
#
# * **Example PMF for a die roll (X = outcome of rolling a fair die):**
#
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1/6
# ,
# 𝑥
# =
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# P(X=x)=
# 6
# 1
# ​
#  ,x=1,2,3,4,5,6

# %% [markdown]
# **2.Continuous Random Variable**
#
# A continuous random variable takes an infinite number of values within a range.
#
# It is associated with continuous probability distributions (e.g., Normal, Exponential).
#
# Probabilities are determined using a Probability Density Function (PDF).
#
# The probability of an exact value is zero (since the area under a single point is zero).
#
#  **Examples:**
# * Height of students in a class.
# * Time taken for a machine to complete a task.
# * Temperature in a city on a given day.
#
# * **Example PDF for a normal distribution (X = human height in cm):**
#
#
#
# ![Screenshot 2025-04-03 214412.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-03 221650.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q3.What is the difference between discrete and continuous distributions?**

# %% [markdown]
# ![Screenshot 2025-04-03 222504.png](data:image/png;base64,...)

# %% [markdown]
# Example Illustrations
# * **Discrete Distribution Example: Binomial (Coin Flips)**
#
#  * Suppose
# 𝑋
# X is the number of heads in 3 coin flips.
#
#  * Possible values:
# 𝑋
# =
# 0
# ,
# 1
# ,
# 2
# ,
# 3
# X=0,1,2,3.
#
#  * PMF: ![Screenshot 2025-04-03 223102.png](data:image/png;base64,...)
#
# * **Continuous Distribution Example: Normal (Heights of Students)**
#  * Suppose represents heights of students in cm.
#
#  * 𝑋 can take any real number within a range (e.g., 150.2 cm, 165.7 cm).
#
#  * PDF: ![Screenshot 2025-04-03 223229.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q4.What are probability distribution functions (PDF)?**

# %% [markdown]
# A Probability Distribution Function (PDF) describes the likelihood of a random variable taking specific values.
#
# **Types of PDFs:**
#
# **1.For Discrete Random Variables** – Uses a Probability Mass Function (PMF):
#
#           𝑃(𝑋 = 𝑥)
#
#
# (Gives probability at specific values.)
#
# **2.For Continuous Random Variables** – Uses a Probability Density Function (PDF):
#
# ![Screenshot 2025-04-03 223822.png](data:image/png;base64,...)
#
# (Probability is given by area under the curve.)

# %% [markdown]
# ## **Q5.How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**

# %% [markdown]
# ![Screenshot 2025-04-03 224532.png](data:image/png;base64,...)

# %% [markdown]
# **PDF vs. CDF Example**
#
# **1. Continuous Random Variable (Height Example)**
#
# * **PDF:**
# 𝑓
# (
# 𝑥
# )
# f(x) shows the likelihood of a person being exactly 170 cm tall.
#
# * **CDF:**
# 𝐹
# (
# 170
# )
# F(170) gives the probability that a person’s height is ≤ 170 cm.
#
# **2. Discrete Random Variable (Dice Example)**
#
# * **PDF (PMF):**
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# 1
# 6
# P(X=3)=
# 6
# 1
# ​
#   (Chance of rolling a 3).
#
# * **CDF:**F(3)=P(X≤3)=P(X=1)+P(X=2)+P(X=3)=
# 3/6.

# %% [markdown]
# ## **Q6.What is a discrete uniform distribution? to the point answer?**

# %% [markdown]
# A Discrete Uniform Distribution is a probability distribution where a finite number of values are equally likely to occur.
#
# **Formula:**
# For
# 𝑋
# X taking
# 𝑛
# n distinct values:
#
# ![Screenshot 2025-04-03 225323.png](data:image/png;base64,...)
#
# **Example:**
# * Rolling a fair 6-sided die:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1/6
# ,
# 𝑥
# =
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
#
# * Selecting a random card from a deck of
# 52: P(X=x)=
# 1/52

# %% [markdown]
# ## **Q7.What are the key properties of a Bernoulli distribution?**

# %% [markdown]
# ![Screenshot 2025-04-03 225820.png](data:image/png;base64,...)

# %% [markdown]
# **Example:**
# * Coin Toss: Head = 1, Tail = 0, with 𝑝=0.5.
#
# * Light Bulb Working (Yes/No): Success (1) if it works, Failure (0) if it doesn’t.

# %% [markdown]
# ## **Q8.What is the binomial distribution, and how is it used in probability?**

# %% [markdown]
# ![Screenshot 2025-04-03 230118.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-03 230251.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q9.What is the Poisson distribution and where is it applied?**

# %% [markdown]
# ![Screenshot 2025-04-03 230513.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-03 230553.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q10.What is a continuous uniform distribution?**

# %% [markdown]
# ![Screenshot 2025-04-03 230917.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-03 231027.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q11.What are the characteristics of a normal distribution?**

# %% [markdown]
# **Characteristics of a Normal Distribution**
#
# **1.Bell-Shaped Curve**
#
# * Symmetrical around the mean.
#
# * Highest probability density at the center.
#
# **2.Mean, Median, and Mode are Equal**
#
# * Located at the center of the distribution.
#
# **3.Defined by Mean (
# 𝜇
# μ) and Standard Deviation (
# 𝜎
# σ)**
#
# * 𝜇
# μ (mean) determines the center.
#
# * 𝜎
# σ (standard deviation) determines the spread.
#
# **4.Probability Density Function (PDF):**
#
# ![Screenshot 2025-04-03 232006.png](data:image/png;base64,...)
#
# **5.Empirical Rule (68-95-99.7 Rule)**
#
# * 68% of data falls within 1σ of the mean.
#
# * 95% falls within 2σ.
#
# * 99.7% falls within 3σ.
#
# **6.Asymptotic Nature**
#
# The tails never touch the x-axis (extend infinitely).
#
# **7.Total Probability = 1**
#
# * The area under the curve sums to 1.
#
# **Applications:**
# * Finance (Stock returns, risk modeling)
# * Biology (Height, weight distributions)
# * Quality Control (Defects in manufacturing)
# * Standardized Testing (IQ scores, SAT scores)

# %% [markdown]
# ## **Q12.What is the standard normal distribution, and why is it important?**

# %% [markdown]
# **Standard Normal Distribution**
# The Standard Normal Distribution is a special case of the normal distribution where:
#
# * Mean (
# 𝜇
# μ) = 0
#
# * Standard Deviation (
# 𝜎
# σ) = 1
#
# * Formula:
#
# ![Screenshot 2025-04-03 232228.png](data:image/png;base64,...)
#
# **Why is it Important?**
#
# **1.Simplifies Probability Calculations**
#
# * Converts any normal distribution into a common scale using the Z-score.
#
# * Allows probabilities to be found using Z-tables.
#
# **2.Enables Comparison Across Different Datasets**
#
# * Standardizes values from different normal distributions for fair comparison.
#
# **3.Foundation for Hypothesis Testing & Confidence Intervals**
#
# * Used in Z-tests, confidence intervals, and statistical inference.
#
# **4.Central Limit Theorem (CLT) Connection**
#
# * Many real-world distributions approximate normality, making the standard normal crucial for probability theory.
#
# **Key Takeaway:** The Standard Normal Distribution is the benchmark for all normal distributions, making statistical analysis easier and more consistent.

# %% [markdown]
# ## **Q13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?**

# %% [markdown]
# Central Limit Theorem (CLT)
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution as the sample size
# 𝑛
# n increases, regardless of the original population distribution.
#
# **Key Points:**
#
# **1.Applies to Any Population Distribution.**
#
# * The population can be skewed, uniform, or any other shape.
#
# * With sufficiently large
# 𝑛, the sample mean follows a normal distribution.
#
# **2.Sampling Distribution of the Mean:**
#
# * **Mean of sample means = Population mean**
# 𝜇
# μ.
#
# * **Standard deviation (Standard Error)** =
#  where
# 𝜎
# σ is the population standard deviation.
#
# **3.Larger Sample Size → Better Approximation**
#
# * A sample size of n≥30 is often sufficient for normality.
#
# * If the original population is normal, any sample size works.
#
# **Why is CLT Critical in Statistics?**
# * **Enables Hypothesis Testing**: Z-tests and t-tests assume normality.
# * **Justifies Confidence Intervals**: Used to estimate population parameters.
# * **Facilitates Real-World Decision Making**: Businesses, medicine, and research rely on sample-based conclusions.
# * **Works Even When Population Distribution is Unknown**: Makes statistical inference universally applicable.
#
# **Key Takeaway:** CLT is the foundation of inferential statistics, allowing us to make reliable predictions about populations using sample data.

# %% [markdown]
# ## **Q14.How does the Central Limit Theorem relate to the normal distribution?**

# %% [markdown]
# **1.Sampling Distribution Becomes Normal**
#
# * According to the CLT, when we take many random samples of size
# 𝑛
# n from any population, the distribution of sample means will approximate a normal distribution as
# 𝑛
# n increases.
#
# **2.Works for Any Population Distribution**
#
# * Even if the original population is skewed, uniform, or bimodal, the sampling distribution of the mean will be approximately normal for sufficiently large
# 𝑛
# n.
#
# **3.Connection to Standard Normal Distribution**
#
# * The sample means follow a normal distribution with:
#
# * Mean:
# 𝜇
# 𝑋 =μ (same as the population mean).
#
# * Standard Error:
# 𝜎
# 𝑋
# ˉ
# =
# a/n (standard deviation decreases as
# 𝑛
# n increases).
#
# * This allows us to use Z-scores and the Standard Normal Distribution for probability calculations.
#
# **4.Key Condition: Large Sample Size**
#
# * If n≥30, the sample mean distribution is approximately normal (often considered sufficient).
#
# * If the original population is already normal, any sample size works.
#
# **Why This Matters?**
# * Justifies Using Normal-Based Statistical Tests (Z-test, t-test, Confidence Intervals, Regression Analysis)
# * Simplifies Probability Calculations with Z-Tables
# * Makes Inferential Statistics Possible
#
# * Key Takeaway: The CLT explains why the normal distribution is so fundamental—it naturally emerges when averaging data from any distribution!

# %% [markdown]
# ## **Q15.What is the application of Z statistics in hypothesis testing?**

# %% [markdown]
# **Applications of Z-Statistics in Hypothesis Testing**
# * **Z-Test for Population Mean:** Tests if a sample mean differs from a known population mean when
# 𝜎
# σ (population standard deviation) is known.
#
# * **Z-Test for Population Proportion:** Compares a sample proportion to a known population proportion.
#
# * **Two-Sample Z-Test:** Compares means of two independent samples when both
# 𝜎
# σ's are known.
#
# * **Confidence Intervals:** Constructs confidence intervals for population means and proportions.
#
# * **Quality Control:** Used in manufacturing to detect defects based on normal distribution assumptions.
#
# * **Key Requirement:** Sample size
# 𝑛
# ≥
# 30
# n≥30 or normally distributed population.

# %% [markdown]
# ## **Q16.How do you calculate a Z-score, and what does it represent?**

# %% [markdown]
# The Z-score (standard score) is calculated using the formula:
#
# ![Screenshot 2025-04-03 234452.png](data:image/png;base64,...)
#
# where:
#
# * 𝑋 = observed value
#
# * 𝜇 = population mean
#
# * 𝜎 = population standard deviation
#
# For a sample:
#
# ![Screenshot 2025-04-03 234633.png](data:image/png;base64,...)
#
# where
# 𝑋
#   is the sample mean and
# 𝑠
# s is the sample standard deviation.

# %% [markdown]
# **What Does a Z-Score Represent?**
# * **Measures how many standard deviations** a data point is from the mean.
# * **Standardizes different datasets**, making comparisons possible.
# * **Positive Z-score:** Value is above the mean.
# * **Negative Z-score**: Value is below the mean.
# * **Z = 0:** Value is exactly at the mean.
#
# * **Key Use:** Used in probability calculations, hypothesis testing, and detecting outliers in datasets.

# %% [markdown]
# ## **Q17.What are point estimates and interval estimates in statistics?**

# %% [markdown]
# Point Estimates vs. Interval Estimates
#
# **1. Point Estimate**
# A single value used to approximate a population parameter.
#
# **Example:** Using the sample mean
# 𝑋
#  to estimate the population mean
# 𝜇
# μ.
#
# * **Common Point Estimates:**
#
# * Sample mean (X) for population mean (
# 𝜇
# μ).
#
# * Sample proportion (
# 𝑝
# ^for population proportion (
# 𝑝).
#
# * Sample variance (
# 𝑠(squrare)) for population variance (
# 𝜎(square).
#
# **2. Interval Estimate**
# A range of values that likely contains the population parameter, with a specified confidence level.
#
# * Example: A 95% confidence interval (CI) for
# 𝜇 might be (50, 60), meaning we are 95% confident 𝜇 falls within this range.
#
# * Formula for CI (for mean,
# 𝜎
# σ known):
#
# ![Screenshot 2025-04-03 235554.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q18.What is the significance of confidence intervals in statistical analysis?**

# %% [markdown]
# **1.Measures Uncertainty**
#
# * Provides a range of values instead of a single estimate, accounting for variability in sample data.
#
# **2.Indicates Precision of Estimates**
#
# * Narrow CI → More precise estimate.
#
# * Wide CI → More variability or smaller sample size.
#
# **3.Supports Decision-Making**
#
# * Used in business, medicine, and research to draw conclusions about populations.
#
# **4.Hypothesis Testing Alternative**
#
# * If the CI excludes a hypothesized value (e.g., population mean), we may reject the null hypothesis.
#
# **5.Applicable Across Fields**
#
# * Used in polling, medical trials, finance, and quality control.

# %% [markdown]
# ## **Q19.What is the relationship between a Z-score and a confidence interval?**

# %% [markdown]
# ![Screenshot 2025-04-04 000224.png](data:image/png;base64,...)
# ![Screenshot 2025-04-04 000326.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q20. How are Z-scores used to compare different distributions?**

# %% [markdown]
# **Standardizes Different Distributions**
#
# * Converts values from different distributions into a common scale (mean = 0, standard deviation = 1).
#
# **Formula for Z-Score:**
# ![Screenshot 2025-04-04 000615.png](data:image/png;base64,...)
#
# * X = observed value
#
# * 𝜇 = mean of the distribution
#
# * 𝜎 = standard deviation of the distribution
#
# **Allows Direct Comparison**
#
# * Different datasets with different means & standard deviations can be compared.
#
# * Example: Comparing test scores from two different exams with different scoring systems.
#
# **Identifies Outliers Across Distributions**
#
# * A high positive Z-score → value is significantly above the mean.
#
# * A negative Z-score → value is below the mean.
#
# * Typically, ∣Z∣>2 or ∣Z∣>3 indicates an outlier.

# %% [markdown]
# ## **Q21.What are the assumptions for applying the Central Limit Theorem**?

# %% [markdown]
# **1. Random Sampling**
#
# * The samples must be randomly selected from the population.
#
# **2. Independent Observations**
#
# * Each observation must not influence another.
#
# * If sampling without replacement, the sample size should be ≤10% of the population.
#
# **3. Sample Size is Large Enough**
#
# * A general rule:
# 𝑛
# ≥
# 30
# n≥30 is sufficient.
#
# * If the population is normally distributed, a smaller
# 𝑛
# n is acceptable.
#
# **4. Finite Variance**
#
# * The population must have a finite mean (
# 𝜇
# μ) and variance (
# 𝜎(square)).

# %% [markdown]
# ## **Q22.What is the concept of expected value in a probability distribution?**

# %% [markdown]
# The expected value (EV) of a random variable represents the long-term average or mean of possible outcomes, weighted by their probabilities. It provides a measure of the central tendency in a probability distribution.
#
# **Formula:**
#
# **1.For Discrete Random Variables:**
#
# ![Screenshot 2025-04-04 001408.png](data:image/png;base64,...)
#
# where:![Screenshot 2025-04-04 001935.png](data:image/png;base64,...)
# * 𝑥𝑖 = possible values of 𝑋
#
# * 𝑃(𝑥𝑖)
# P(xi) = probability of each
# 𝑥
# 𝑖
#
# **2.For Continuous Random Variables:**
#
#
# where
# 𝑓
# (
# 𝑥
# )
# f(x) is the probability density function (PDF).

# %% [markdown]
# **Key Insights:**
# * Represents the weighted average outcome over many trials.
# * Used in decision-making, finance, and risk analysis.
# * Helps determine fair values in gambling, insurance, and economics.
#
# **Example:** In a fair dice roll,
#
# ![Screenshot 2025-04-04 002136.png](data:image/png;base64,...)

# %% [markdown]
# ## **Q23. How does a probability distribution relate to the expected outcome of a random variable?**

# %% [markdown]
# **Defines Likelihood of Outcomes**
#
# * A probability distribution assigns probabilities to all possible values of a random variable.
#
# * The expected outcome (expected value,
# 𝐸
# (
# 𝑋
# ) is calculated using this distribution.
#
# **Expected Value as a Weighted Average**
#
# * The expected value is the sum (or integral) of all possible values weighted by their probabilities:
#
# * **For Discrete Variables:**
#
# ![Screenshot 2025-04-04 002445.png](data:image/png;base64,...)
# * **For Continuous Variables:**
#
# ![Screenshot 2025-04-04 002646.png](data:image/png;base64,...)
# **Determines the Theoretical Long-Run Average**
#
# * Over many repetitions, the observed average converges to
# 𝐸
# (
# 𝑋
# ).
# * Example: In a fair dice roll,
# 𝐸
# (
# 𝑋
# )
# =
# 3.5
# E(X)=3.5, meaning on average, rolls will center around 3.5 over time.

# %% [markdown]
# # ***PRACTICAL***

# %% [markdown]
# ## **Q1.Write a Python program to generate a random variable and display its value.**

# %%
import random

# Generating a discrete random variable (e.g., rolling a die)
discrete_var = random.randint(1, 6)  # Simulates a fair 6-sided die roll

# Generating a continuous random variable (e.g., from a normal distribution)
continuous_var = random.uniform(0, 1)  # Generates a random float between 0 and 1

print(f"Discrete Random Variable (Dice Roll): {discrete_var}")
print(f"Continuous Random Variable (Uniform Distribution): {continuous_var:.4f}")
# Out:
# Discrete Random Variable (Dice Roll): 6
# Continuous Random Variable (Uniform Distribution): 0.6208

# %% [markdown]
# **How It Works:**
# * random.randint(1,6): Generates a discrete random variable between 1 and 6 (like rolling a die).
#
# * random.uniform(0,1): Generates a continuous random variable between 0 and 1.

# %% [markdown]
# ## **Q2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution (e.g., a fair die: 1 to 6)
low, high = 1, 6

# Generate a discrete uniform distribution
x = np.arange(low, high + 1)
pmf = randint.pmf(x, low, high + 1)  # Probability mass function

# Plot the PMF
plt.bar(x, pmf, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel("Random Variable (X)")
plt.ylabel("Probability P(X)")
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.ylim(0, max(pmf) + 0.05)

# Show probability values on bars
for i, p in zip(x, pmf):
    plt.text(i, p + 0.01, f"{p:.2f}", ha='center', fontsize=12)

plt.show()

# %% [markdown]
# **Explanation:**
# * randint.pmf(x, low, high + 1): Computes the PMF for a discrete uniform distribution.
# * plt.bar(): Plots the probability values as a bar chart.
# * Text Labels: Displays the probability on each bar for clarity.

# %% [markdown]
# ## **Q3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.**

# %%
from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    """
    Computes the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    p (float): Probability of success (0 ≤ p ≤ 1)
    x (int): Value of the random variable (0 or 1)

    Returns:
    float: Probability P(X = x)
    """
    if x not in [0, 1]:
        return "x must be 0 or 1 for Bernoulli distribution"

    return bernoulli.pmf(x, p)  # PMF for Bernoulli is same as PDF

# Example Usage:
p = 0.6  # Probability of success
print(f"P(X=0): {bernoulli_pdf(p, 0)}")
print(f"P(X=1): {bernoulli_pdf(p, 1)}")
# Out:
# P(X=0): 0.4000000000000001
# P(X=1): 0.6

# %% [markdown]
# **Explanation:**
# * **Bernoulli Distribution Formula:**
#
# ![Screenshot 2025-04-04 003323.png](data:image/png;base64,...)
#
# bernoulli.pmf(x, p): Computes
# 𝑃
# (
# 𝑋
# =
# 𝑥
# ) using SciPy.
# * **Input Constraints:** Ensures𝑥 can only be 0 or 1.

# %% [markdown]
# ## **Q4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10   # Number of trials
p = 0.5  # Probability of success

# Simulate 10000 samples from the binomial distribution
samples = np.random.binomial(n, p, 10000)

# Plot histogram of the samples
plt.hist(samples, bins=np.arange(n+2)-0.5, density=True, alpha=0.7, color='skyblue', edgecolor='black', rwidth=0.8)

# Overlay the theoretical binomial probability mass function (PMF)
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'ro-', markersize=8, label='Theoretical PMF')

# Labels and title
plt.xlabel("Number of Successes (X)")
plt.ylabel("Probability")
plt.title(f"Binomial Distribution Histogram (n={n}, p={p})")
plt.xticks(x)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# **Explanation:**
# * Simulates 10,000 trials of a binomial distribution using np.random.binomial(n, p, size).
# * Plots a histogram to visualize the distribution.
# * Overlays the theoretical PMF (red dots) using scipy.stats.binom.pmf().
# * Uses density=True so the histogram matches the probability values.

# %% [markdown]
# ## **Q5.Create a Poisson distribution and visualize it using Python.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the Poisson distribution parameter (mean number of events per interval)
lambda_ = 5  # Average number of occurrences

# Generate values for the Poisson distribution
x = np.arange(0, 15)  # Possible number of occurrences (0 to 14)
pmf = poisson.pmf(x, lambda_)  # Compute the probability mass function (PMF)

# Plot the Poisson distribution
plt.bar(x, pmf, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel("Number of Events (X)")
plt.ylabel("Probability P(X)")
plt.title(f"Poisson Distribution (λ={lambda_})")

# Display probability values above bars
for i, p in zip(x, pmf):
    plt.text(i, p + 0.005, f"{p:.3f}", ha='center', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Explanation:**
# * Defines a Poisson distribution with
# 𝜆
# =
# 5 (mean event count per interval).
# * Computes the PMF using poisson.pmf(x, lambda_).
# * Plots a bar chart to visualize the probability of different event counts.
# * Displays probabilities above each bar for clarity.

# %% [markdown]
# ## **Q6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution
low, high = 1, 6  # Example: Rolling a fair 6-sided die

# Generate x values (possible outcomes)
x = np.arange(low, high + 1)

# Compute the CDF using scipy.stats
cdf = randint.cdf(x, low, high + 1)

# Plot the CDF
plt.step(x, cdf, where='mid', color='blue', label="CDF")
plt.scatter(x, cdf, color='red', zorder=3)  # Add markers for clarity

# Labels and title
plt.xlabel("Random Variable (X)")
plt.ylabel("Cumulative Probability P(X ≤ x)")
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.yticks(np.round(cdf, 2))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# ## **Q7.Generate a continuous uniform distribution using NumPy and visualize it.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define the range of the uniform distribution
a, b = 2, 10  # Lower and upper bounds

# Generate 10,000 random samples from the uniform distribution
samples = np.random.uniform(a, b, 10000)

# Plot the histogram of the samples
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label="Sampled Data")

# Theoretical PDF for the uniform distribution
x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, a, b - a)  # PDF of uniform distribution
plt.plot(x, pdf, 'r-', lw=2, label="Theoretical PDF")

# Labels and title
plt.xlabel("Value (X)")
plt.ylabel("Density")
plt.title(f"Continuous Uniform Distribution (a={a}, b={b})")
# Out:
# Text(0.5, 1.0, 'Continuous Uniform Distribution (a=2, b=10)')

# %% [markdown]
# **Explanation:**
# * Defines a uniform distribution between [2,10].
# * Generates random samples using np.random.uniform(a, b, 10000).
# * Plots a histogram of the generated samples.
# * Overlays the theoretical PDF using scipy.stats.uniform.pdf().
# * Uses density=True to match the histogram with the probability density function (PDF).

# %% [markdown]
# ## **Q8.Simulate data from a normal distribution and plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the parameters of the normal distribution
mu, sigma = 0, 1  # Mean (μ) and Standard Deviation (σ)

# Generate 10,000 random samples from the normal distribution
samples = np.random.normal(mu, sigma, 10000)

# Plot histogram of the samples
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label="Sampled Data")

# Theoretical Normal Distribution (PDF)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)  # X values
pdf = norm.pdf(x, mu, sigma)  # Compute PDF
plt.plot(x, pdf, 'r-', lw=2, label="Theoretical PDF")

# Labels and title
plt.xlabel("Value (X)")
plt.ylabel("Density")
plt.title("Histogram of Normal Distribution (μ=0, σ=1)")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# **Explanation:**
# * Defines a normal distribution with mean (μ) = 0 and standard deviation (σ) = 1.
# * Generates 10,000 random samples using np.random.normal(mu, sigma, 10000).
# * Plots a histogram to visualize the sample distribution.
# * Overlays the theoretical PDF (red curve) using scipy.stats.norm.pdf().
# * Uses density=True so the histogram aligns with the probability density function (PDF).

# %% [markdown]
# ## **Q9.Write a Python function to calculate Z-scores from a dataset and plot them.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

def calculate_and_plot_zscores(data):
    """
    Calculates Z-scores for a given dataset and plots them as a histogram.

    Parameters:
    data (array-like): Input dataset

    Returns:
    z_scores (numpy array): Computed Z-scores
    """
    # Calculate Z-scores
    z_scores = zscore(data)

    # Plot the histogram of Z-scores
    plt.figure(figsize=(8, 5))
    sns.histplot(z_scores, bins=30, kde=True, color='skyblue', edgecolor='black', alpha=0.7)

    # Add mean and standard deviation lines
    plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (Z=0)")
    plt.axvline(1, color='green', linestyle='dashed', linewidth=2, label="Z = 1")
    plt.axvline(-1, color='green', linestyle='dashed', linewidth=2, label="Z = -1")

    # Labels and title
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.title("Histogram of Z-scores")
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Show the plot
    plt.show()

    return z_scores

# Example usage:
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(50, 15, 1000)  # Generate normal distributed data
z_scores = calculate_and_plot_zscores(sample_data)

# %% [markdown]
# **Explanation:**
# * Computes Z-scores using scipy.stats.zscore(data).
# * Plots a histogram using seaborn.histplot() for better visualization.
# * Overlays reference lines at Z=0 (mean) and Z=±1 (standard deviation).
# * Uses a normal dataset (np.random.normal(50, 15, 1000)) for testing.

# %% [markdown]
# ## **Q10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def central_limit_theorem_demo(sample_size=30, num_samples=1000):
    """
    Demonstrates the Central Limit Theorem (CLT) using a non-normal distribution (Exponential).

    Parameters:
    sample_size (int): Size of each sample drawn from the non-normal distribution.
    num_samples (int): Number of samples to draw.
    """
    # Generate an exponentially distributed population (highly skewed, non-normal)
    population = np.random.exponential(scale=2, size=10000)

    # Collect sample means
    sample_means = [np.mean(np.random.choice(population, sample_size, replace=True)) for _ in range(num_samples)]

    # Plot original population distribution
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    sns.histplot(population, bins=50, kde=True, color='red', edgecolor='black', alpha=0.7)
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.title("Original Exponential Distribution (Skewed)")

    # Plot distribution of sample means
    plt.subplot(1, 2, 2)
    sns.histplot(sample_means, bins=50, kde=True, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel("Sample Mean")
    plt.ylabel("Frequency")
    plt.title(f"Sampling Distribution (Sample Size = {sample_size})\n Approximates Normal")

    plt.tight_layout()
    plt.show()

# Run the CLT demonstration
central_limit_theorem_demo(sample_size=30, num_samples=1000)

# %% [markdown]
# **Explanation:**
# * Generates a non-normal (exponential) population with np.random.exponential().
# * Draws num_samples random samples, each of size sample_size, from the population.
# * Computes the mean of each sample and stores them in sample_means.
# * Plots two histograms:
#
#  * Left: Original exponential distribution (highly skewed).
#
#  * Right: Distribution of sample means (becomes approximately normal due to CLT).

# %% [markdown]
# ## **Q11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def verify_clt(sample_size=30, num_samples=1000, mu=50, sigma=15):
    """
    Simulates multiple samples from a normal distribution and verifies CLT.

    Parameters:
    sample_size (int): Number of observations in each sample.
    num_samples (int): Number of samples drawn.
    mu (float): Mean of the normal population.
    sigma (float): Standard deviation of the normal population.
    """
    # Generate a normal population
    population = np.random.normal(mu, sigma, 10000)

    # Collect sample means
    sample_means = [np.mean(np.random.choice(population, sample_size, replace=True)) for _ in range(num_samples)]

    # Plot original normal population
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    sns.histplot(population, bins=50, kde=True, color='red', edgecolor='black', alpha=0.7)
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.title("Original Normal Distribution")

    # Plot distribution of sample means
    plt.subplot(1, 2, 2)
    sns.histplot(sample_means, bins=50, kde=True, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel("Sample Mean")
    plt.ylabel("Frequency")
    plt.title(f"Sampling Distribution of the Mean (Sample Size = {sample_size})")

    plt.tight_layout()
    plt.show()

# Run CLT verification
verify_clt(sample_size=30, num_samples=1000)

# %% [markdown]
# **Explanation:**
# * Generates a normal population with np.random.normal(mu, sigma, 10000).
# * Takes multiple random samples (num_samples), each of size sample_size.
# * Computes and stores the sample means to form a sampling distribution.
# * Plots two histograms:
#
#  * Left: Original normal distribution.
#
#  * Right: Sample means, which should also be normal due to CLT.

# %% [markdown]
# ## **Q12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    """
    Plots the standard normal distribution (mean = 0, standard deviation = 1).
    """
    # Define the range for X values
    x = np.linspace(-4, 4, 1000)

    # Compute the probability density function (PDF)
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the Standard Normal Distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, 'r-', linewidth=2, label="Standard Normal (μ=0, σ=1)")

    # Highlight standard deviation ranges
    plt.fill_between(x, pdf, where=(x >= -1) & (x <= 1), color='blue', alpha=0.3, label="68% (1σ)")
    plt.fill_between(x, pdf, where=(x >= -2) & (x <= 2), color='green', alpha=0.2, label="95% (2σ)")
    plt.fill_between(x, pdf, where=(x >= -3) & (x <= 3), color='yellow', alpha=0.1, label="99.7% (3σ)")

    # Add labels and title
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.title("Standard Normal Distribution (Z ~ N(0,1))")
    plt.axvline(0, color='black', linestyle='dashed', linewidth=1, label="Mean (Z=0)")
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Call the function to plot
plot_standard_normal()

# %% [markdown]
# **Explanation:**
# * Generates values for Z in the range [-4, 4] using np.linspace().
# * Computes the standard normal PDF using scipy.stats.norm.pdf().
# * Plots the standard normal curve with a red line.
# * Highlights the standard deviation regions:
#
# * Blue (68%) → Within 1σ.
#
# * Green (95%) → Within 2σ.
#
# * Yellow (99.7%) → Within 3σ.
#  * Adds labels, mean line (Z=0), and a legend for clarity.

# %% [markdown]
# ## **Q13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def binomial_distribution(n=10, p=0.5, size=1000):
    """
    Generates random variables from a Binomial distribution and calculates probabilities.

    Parameters:
    n (int): Number of trials
    p (float): Probability of success in each trial
    size (int): Number of random variables to generate

    Returns:
    None
    """
    # Generate binomially distributed random variables
    random_vars = np.random.binomial(n, p, size)

    # Calculate probability mass function (PMF) for each possible outcome (0 to n)
    x = np.arange(0, n + 1)
    pmf_values = binom.pmf(x, n, p)

    # Plot histogram of generated random variables
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.hist(random_vars, bins=n+1, density=True, alpha=0.6, color='blue', edgecolor='black')
    plt.xlabel("Number of Successes")
    plt.ylabel("Frequency")
    plt.title(f"Histogram of Binomial Distribution (n={n}, p={p})")

    # Plot the PMF of the binomial distribution
    plt.subplot(1, 2, 2)
    plt.bar(x, pmf_values, color='red', alpha=0.7, edgecolor='black')
    plt.xlabel("Number of Successes")
    plt.ylabel("Probability")
    plt.title(f"Binomial PMF (n={n}, p={p})")

    plt.tight_layout()
    plt.show()

# Call the function
binomial_distribution(n=10, p=0.5, size=1000)

# %% [markdown]
# **Explanation:**
# * Generates binomially distributed random variables using np.random.binomial(n, p, size).
# * Computes the probability mass function (PMF) using scipy.stats.binom.pmf().
# * Plots two graphs:
#
#  * Left: A histogram of the generated random variables.
#
#  * Right: The exact PMF of the binomial distribution.

# %% [markdown]
# ## **Q14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data, value):
    """
    Calculates the Z-score of a given data point.

    Parameters:
    data (list or numpy array): The dataset
    value (float): The specific data point for which to calculate the Z-score

    Returns:
    float: The Z-score of the given value
    """
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)  # Sample standard deviation
    z_score = (value - mean) / std_dev
    return z_score

def plot_standard_normal(z_score):
    """
    Plots the standard normal distribution and highlights the Z-score position.

    Parameters:
    z_score (float): The calculated Z-score to be marked on the plot
    """
    # Define range for the standard normal distribution
    x = np.linspace(-4, 4, 1000)
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the standard normal distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, 'r-', linewidth=2, label="Standard Normal (μ=0, σ=1)")

    # Highlight the Z-score position
    plt.axvline(z_score, color='blue', linestyle='dashed', linewidth=2, label=f"Z-score = {z_score:.2f}")

    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.title("Standard Normal Distribution with Z-score")
    plt.legend()
    plt.grid()
    plt.show()

# Example usage
data = np.random.normal(loc=50, scale=10, size=100)  # Generate sample data
value = 55  # Data point to analyze

# Calculate Z-score
z_score = calculate_z_score(data, value)

# Print Z-score
print(f"The Z-score for {value} is: {z_score:.2f}")

# Plot the standard normal distribution and highlight the Z-score
plot_standard_normal(z_score)
# Out:
# The Z-score for 55 is: 0.43

# %% [markdown]
# **Explanation:**
# * Calculates the Z-score using the formula:
#
# ![Screenshot 2025-04-04 005805.png](data:image/png;base64,...)
#
# where
# 𝑋 is the data point,
# 𝜇 is the mean, and
# 𝜎 is the standard deviation.
#
# * Generates a sample dataset from a normal distribution.
# * Highlights the Z-score on the standard normal curve using a vertical dashed line.

# %% [markdown]
# ## **Q15.Implement hypothesis testing using Z-statistics for a sample dataset.**

# %% [markdown]
# **Problem Statement:**
# Suppose we want to test whether the mean weight of a population is 50 kg based on a sample dataset.
# We assume a known population standard deviation (which allows us to use Z-statistics).
#
# **Hypotheses:**
#
# * Null Hypothesis (
# 𝐻
# 0
#  ): The population mean is 50 kg.
#
# * Alternative Hypothesis (
# 𝐻
# 𝐴): The population mean is not 50 kg (two-tailed test)

# %%
import numpy as np
import scipy.stats as stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a Z-test for a sample dataset.

    Parameters:
    sample (list or np.array): Sample dataset
    pop_mean (float): Hypothesized population mean (H0)
    pop_std (float): Known population standard deviation
    alpha (float): Significance level (default = 0.05)

    Returns:
    None
    """
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Calculate the Z-score
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))

    # Calculate p-value for two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.5f}")

    # Conclusion
    if p_value < alpha:
        print("Reject the Null Hypothesis (H0): Significant difference detected.")
    else:
        print("Fail to Reject the Null Hypothesis (H0): No significant difference detected.")

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=51, scale=5, size=30)  # Sample data (mean=51, std=5, n=30)
population_mean = 50  # Hypothesized mean (H0)
population_std = 5    # Known population standard deviation

# Perform Z-test
z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 50.06
# Z-score: 0.06
# P-value: 0.94824
# Fail to Reject the Null Hypothesis (H0): No significant difference detected.

# %% [markdown]
# **Explanation:**
# * Step 1: Compute sample mean and sample size.
# * Step 2: Calculate Z-score using the formula:
# ![Screenshot 2025-04-04 010246.png](data:image/png;base64,...)
#
# where:
#
# * 𝑋 = sample mean
#
# * 𝜇 = population mean (null hypothesis)
#
# * 𝜎 = known population standard deviation
#
# * 𝑛 = sample size
#
# **Step 3:** Compute the p-value (probability of observing the result if
# 𝐻0 is true).
#
# **Step 4:** Compare p-value with significance level (
# 𝛼 = α = 0.05):**
#
# * If p-value < 0.05 → Reject
# 𝐻
# 0 (significant difference).
#
# * Otherwise → Fail to reject
# 𝐻
# 0 (no significant difference).

# %% [markdown]
# ## **Q16.Create a confidence interval for a dataset using Python and interpret the result.**

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    """
    Calculates the confidence interval for a given dataset.

    Parameters:
    data (list or np.array): Sample dataset
    confidence (float): Confidence level (default = 0.95 for 95% CI)

    Returns:
    tuple: Lower and upper bound of the confidence interval
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation (ddof=1 for unbiased estimate)
    n = len(data)

    # Calculate the margin of error using the t-distribution (for small samples)
    t_value = stats.t.ppf((1 + confidence) / 2, df=n-1)  # t-critical value
    margin_of_error = t_value * (sample_std / np.sqrt(n))

    # Compute confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=70, scale=10, size=30)  # Sample of n=30, mean=70, std=10

# Calculate confidence interval
lower, upper, sample_mean = confidence_interval(sample_data)

# Print result
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
print("Interpretation: We are 95% confident that the true population mean lies within this range.")
# Out:
# Sample Mean: 68.12
# 95% Confidence Interval: (64.76, 71.48)
# Interpretation: We are 95% confident that the true population mean lies within this range.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Compute sample mean and sample standard deviation.
#
# **Step 2:** Use the t-distribution for small samples (
# 𝑛
# <
# 30):
#
#
# where:
#
# * 𝑡
# 𝛼
# /
# 2
# t
# α/2
# ​
#   = t-critical value (from scipy.stats.t.ppf)
#
# * 𝑠 = sample standard deviation
#
# * 𝑛 = sample size
#
# **Step 3:** Compute confidence interval:
#
# (
# 𝑋
# ˉ
# −
# margin of error
# ,
# 𝑋
# ˉ
# +
# margin of error
# )
#
# where
# 𝑋 is the sample mean.
#
# **Step 4:** Interpret the result → The confidence interval tells us that we are 95% confident that the true population mean lies within this range.

# %% [markdown]
# ## **Q17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.**

# %% [markdown]
# **Problem Statement:**
# We generate a random dataset from a normal distribution and compute a 95% confidence interval for its true population mean.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def confidence_interval(data, confidence=0.95):
    """
    Calculates the confidence interval for a given dataset.

    Parameters:
    data (list or np.array): Sample dataset
    confidence (float): Confidence level (default = 0.95 for 95% CI)

    Returns:
    tuple: Lower and upper bound of the confidence interval
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation (unbiased)
    n = len(data)

    # Calculate margin of error using the t-distribution (for small samples)
    t_value = stats.t.ppf((1 + confidence) / 2, df=n-1)  # t-critical value
    margin_of_error = t_value * (sample_std / np.sqrt(n))

    # Compute confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=70, scale=10, size=30)  # Mean=70, Std=10, n=30

# Step 2: Compute confidence interval
lower, upper, sample_mean = confidence_interval(sample_data)

# Step 3: Plot histogram of the sample data
plt.figure(figsize=(8,5))
plt.hist(sample_data, bins=10, color='skyblue', edgecolor='black', alpha=0.7, density=True)
plt.axvline(sample_mean, color='red', linestyle='dashed', linewidth=2, label=f"Sample Mean = {sample_mean:.2f}")
plt.axvline(lower, color='green', linestyle='dashed', linewidth=2, label=f"Lower CI = {lower:.2f}")
plt.axvline(upper, color='green', linestyle='dashed', linewidth=2, label=f"Upper CI = {upper:.2f}")
plt.title("Histogram of Sample Data with Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.show()

# Step 4: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
print("Interpretation: We are 95% confident that the true population mean lies within this range.")
# Out:
# Sample Mean: 68.12
# 95% Confidence Interval: (64.76, 71.48)
# Interpretation: We are 95% confident that the true population mean lies within this range.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Generate a random dataset from a normal distribution.
#
# **Step 2:** Compute sample mean and confidence interval using the t-distribution.
#
# **Step 3:** Plot a histogram of the sample data and mark the confidence interval.
#
# **Step 4:** Interpret the result.

# %% [markdown]
# ## **Q18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.**

# %% [markdown]
# **Problem Statement:**
#
# We compute the PDF for a normal distribution and visualize it using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the normal distribution parameters
mean = 0       # Mean (μ)
std_dev = 1    # Standard Deviation (σ)

# Step 2: Generate values for the x-axis
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)  # Range: μ ± 4σ

# Step 3: Calculate the Probability Density Function (PDF)
pdf = stats.norm.pdf(x, mean, std_dev)

# Step 4: Plot the PDF
plt.figure(figsize=(8,5))
plt.plot(x, pdf, color='blue', label=f'N({mean}, {std_dev}²)')
plt.fill_between(x, pdf, color='lightblue', alpha=0.5)  # Shade under the curve
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean = {mean}")
plt.title("Normal Distribution PDF")
plt.xlabel("X values")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Define parameters: Mean (μ) and Standard Deviation (σ).
#
# **Step 2:** Generate x-values in the range μ ± 4σ.
#
# **Step 3:** Calculate the PDF using scipy.stats.norm.pdf().
#
# **Step 4:** Plot the PDF and shade the area under the curve.

# %% [markdown]
# ## **Q19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.**

# %% [markdown]
# **Problem Statement:**
#
# We compute the CDF for a Poisson distribution and visualize it using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the Poisson distribution parameter (λ)
lambda_val = 4  # Average number of occurrences in a fixed interval

# Step 2: Generate values for x (possible event counts)
x = np.arange(0, 15)  # Possible event occurrences from 0 to 14

# Step 3: Calculate the Cumulative Distribution Function (CDF)
poisson_cdf = stats.poisson.cdf(x, mu=lambda_val)

# Step 4: Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, poisson_cdf, where='mid', color='blue', label=f'Poisson(λ={lambda_val})')
plt.scatter(x, poisson_cdf, color='red')
plt.xlabel("Number of Occurrences (k)")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF) of Poisson Distribution")
plt.grid()
plt.legend()
plt.show()

# Step 5: Interpret results
for k, cdf_val in zip(x, poisson_cdf):
    print(f"P(X ≤ {k}) = {cdf_val:.4f}")
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Define the Poisson distribution parameter (λ = 4).
#
# **Step 2:** Generate x-values (possible number of occurrences).
#
# **Step 3:** Compute the CDF using scipy.stats.poisson.cdf().
#
# **Step 4:** Plot the CDF using a step plot (as Poisson is discrete).
#
# **Step 5:** Interpret the probability values.

# %% [markdown]
# ## **Q20.Simulate a random variable using a continuous uniform distribution and calculate its expected value.**

# %% [markdown]
# **Problem Statement:**
#
# We generate random samples from a continuous uniform distribution, then calculate and interpret its expected value.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define the continuous uniform distribution range
a, b = 2, 10  # Lower and upper bounds

# Step 2: Generate random variables from the uniform distribution
np.random.seed(42)  # For reproducibility
sample_size = 10000
uniform_samples = np.random.uniform(a, b, sample_size)

# Step 3: Compute the Expected Value (Theoretical and Empirical)
expected_value_theoretical = (a + b) / 2  # Formula for expected value of uniform(a, b)
expected_value_empirical = np.mean(uniform_samples)  # Mean of the sampled data

# Step 4: Plot the histogram
plt.figure(figsize=(8,5))
plt.hist(uniform_samples, bins=30, color='skyblue', edgecolor='black', density=True)
plt.axvline(expected_value_theoretical, color='red', linestyle='dashed', linewidth=2, label=f"Theoretical E(X) = {expected_value_theoretical:.2f}")
plt.axvline(expected_value_empirical, color='green', linestyle='dashed', linewidth=2, label=f"Empirical E(X) = {expected_value_empirical:.2f}")
plt.title("Continuous Uniform Distribution")
plt.xlabel("X values")
plt.ylabel("Density")
plt.legend()
plt.grid()
plt.show()

# Step 5: Print results
print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
print(f"Empirical Expected Value: {expected_value_empirical:.2f}")
print("Interpretation: The empirical expected value approximates the theoretical mean as sample size increases.")
# Out:
# Theoretical Expected Value: 6.00
# Empirical Expected Value: 5.95
# Interpretation: The empirical expected value approximates the theoretical mean as sample size increases.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Define the lower (a) and upper (b) bounds for the uniform distribution.
#
# **Step 2:** Generate random samples from np.random.uniform(a, b, size).
#
# **Step 3:** Compute expected value:
#
#  * Theoretical formula:
# 𝐸
# (
# 𝑋
# )
# =
# 𝑎
# +
# 𝑏/
# 2
#
# ​
#
#
#  * Empirical: Mean of the generated samples.
#
# **Step 4:** Plot a histogram of the generated values.
#
# **Step 5:** Print and compare the theoretical vs empirical expected values.

# %% [markdown]
# ## **Q21.Write a Python program to compare the standard deviations of two datasets and visualize the difference.**

# %% [markdown]
# **Problem Statement:**
#
# We generate two datasets with different standard deviations, calculate them, and visualize the difference using histograms and box plots.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets with different standard deviations
np.random.seed(42)  # For reproducibility
dataset1 = np.random.normal(loc=50, scale=5, size=1000)   # Mean=50, Std=5
dataset2 = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std=15

# Step 2: Calculate standard deviations
std1 = np.std(dataset1, ddof=1)  # Sample standard deviation (ddof=1)
std2 = np.std(dataset2, ddof=1)

# Step 3: Plot histograms
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(dataset1, bins=30, alpha=0.7, color='blue', edgecolor='black', label=f'STD = {std1:.2f}')
plt.hist(dataset2, bins=30, alpha=0.7, color='red', edgecolor='black', label=f'STD = {std2:.2f}')
plt.title("Histogram of Datasets")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.legend()
plt.grid()

# Step 4: Plot box plots for comparison
plt.subplot(1, 2, 2)
plt.boxplot([dataset1, dataset2], labels=['Dataset 1 (σ=5)', 'Dataset 2 (σ=15)'])
plt.title("Box Plot Comparison")
plt.ylabel("Values")
plt.grid()

plt.tight_layout()
plt.show()

# Step 5: Print standard deviation values
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
print("Interpretation: Dataset 2 has a larger spread, indicating higher variability.")
# Out:
# <ipython-input-23-7d238e30f0f3>:27: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([dataset1, dataset2], labels=['Dataset 1 (σ=5)', 'Dataset 2 (σ=15)'])
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96
# Interpretation: Dataset 2 has a larger spread, indicating higher variability.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Generate two datasets from a normal distribution with the same mean but different standard deviations (σ = 5 and σ = 15).
#
# **Step 2:** Compute standard deviations using np.std().
#
# **Step 3** Plot histograms to visualize the spread of data.
#
# **Step 4:** Plot box plots for direct comparison.
#
# **Step 5:** Print standard deviation values and interpret the results.

# %% [markdown]
# ## **Q22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.**

# %% [markdown]
# **Problem Statement:**
#
# We generate a dataset from a normal distribution, then compute and interpret:
#
# * **Range** = Max Value - Min Value
#
# * **Interquartile Range (IQR)** = Q3 - Q1 (Difference between 75th and 25th percentiles)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate Interquartile Range (IQR)
Q1 = np.percentile(data, 25)  # 25th percentile
Q3 = np.percentile(data, 75)  # 75th percentile
IQR = Q3 - Q1

# Step 4: Plot Box Plot for visualization
plt.figure(figsize=(8, 5))
sns.boxplot(data, color="skyblue")
plt.title("Box Plot of the Dataset")
plt.xlabel("Values")
plt.grid()

# Step 5: Print Results
print(f"Range of Dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
print("Interpretation: IQR measures data spread within the middle 50%, while range shows full data spread.")

plt.show()
# Out:
# Range of Dataset: 70.94
# Interquartile Range (IQR): 12.96
# Interpretation: IQR measures data spread within the middle 50%, while range shows full data spread.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Generate normally distributed data with np.random.normal().
#
# **Step 2:** Compute Range using max - min.
#
# **Step 3:** Compute Interquartile Range (IQR) using the 25th and 75th percentiles.
#
# **Step 4:** Visualize the Box Plot to see data spread.
#
# **Step 5:** Print and interpret the results.

# %% [markdown]
# ## **Q23.Implement Z-score normalization on a dataset and visualize its transformation.**

# %% [markdown]
# **What is Z-score normalization?**
#
# Z-score normalization (also called standardization) transforms a dataset to have:
#
# * Mean (μ) = 0
#
# * Standard Deviation (σ) = 1
#
# Each data point is converted using the formula:
# ![Screenshot 2025-04-04 013652.png](data:image/png;base64,...)
#
# where:
#
# * 𝑋 is the original value,
#
# * 𝜇 is the mean,
#
# * 𝜎 is the standard deviation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std=15

# Step 2: Compute Mean and Standard Deviation
mean = np.mean(data)
std_dev = np.std(data)

# Step 3: Apply Z-score normalization
z_scores = (data - mean) / std_dev

# Step 4: Plot before and after normalization
plt.figure(figsize=(12, 5))

# Original Data Histogram
plt.subplot(1, 2, 1)
sns.histplot(data, bins=30, kde=True, color="blue", edgecolor="black")
plt.axvline(mean, color="red", linestyle="dashed", label=f"Mean={mean:.2f}")
plt.title("Original Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

# Normalized Data Histogram
plt.subplot(1, 2, 2)
sns.histplot(z_scores, bins=30, kde=True, color="green", edgecolor="black")
plt.axvline(0, color="red", linestyle="dashed", label="Mean=0 (Normalized)")
plt.title("Z-score Normalized Data Distribution")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()

# Step 5: Print Mean & Standard Deviation after Normalization
print(f"Original Mean: {mean:.2f}, Original Std Dev: {std_dev:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Normalized Std Dev: {np.std(z_scores):.2f}")
# Out:
# Original Mean: 50.29, Original Std Dev: 14.68
# Normalized Mean: 0.00, Normalized Std Dev: 1.00

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Generate a normally distributed dataset with mean = 50 and std dev = 15.
#
# **Step 2:** Compute the dataset’s mean and standard deviation.
#
# **Step 3:** Apply Z-score normalization using the formula
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
#
# **Step 4:** Visualize the data before and after normalization using histograms.
#
# **Step 5:** Print the original and normalized mean & standard deviation.

# %% [markdown]
# ## **Q24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.**

# %% [markdown]
# **What are Skewness & Kurtosis?**
#
# **1.Skewness:** Measures asymmetry in the data distribution.
#
# * Skewness = 0 → Symmetric (Normal distribution).
#
# * Skewness > 0 → Right-skewed (Positive skew).
#
# * Skewness < 0 → Left-skewed (Negative skew).
#
# **2.Kurtosis:** Measures tailedness (peak/sharpness) of the distribution.
#
# * Kurtosis = 3 → Normal distribution (Mesokurtic).
#
# * Kurtosis > 3 → Heavy tails (Leptokurtic).
#
# * Kurtosis < 3 → Light tails (Platykurtic).

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def compute_skewness_kurtosis(data):
    skewness = stats.skew(data)  # Measure of asymmetry
    kurtosis = stats.kurtosis(data, fisher=True)  # Excess kurtosis (subtracts 3)

    return skewness, kurtosis

# Step 1: Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10

# Step 2: Compute Skewness and Kurtosis
skewness, kurtosis = compute_skewness_kurtosis(data)

# Step 3: Plot the Histogram
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=True, color="skyblue", edgecolor="black")
plt.axvline(np.mean(data), color="red", linestyle="dashed", label=f"Mean={np.mean(data):.2f}")
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid()

# Step 4: Print results
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis (Excess): {kurtosis:.4f}")
print("Interpretation:")
print("- Skewness ≈ 0 → Symmetric distribution.")
print("- Kurtosis ≈ 0 → Normal-like tail behavior.")

plt.show()
# Out:
# Skewness: 0.1168
# Kurtosis (Excess): 0.0662
# Interpretation:
# - Skewness ≈ 0 → Symmetric distribution.
# - Kurtosis ≈ 0 → Normal-like tail behavior.

# %% [markdown]
# **Explanation:**
#
# **Step 1:** Generate normally distributed data with mean = 50 and std dev = 10.
#
# **Step 2:** Compute skewness (asymmetry) and kurtosis (tailedness).
#
# **Step 3:** Plot the histogram to visualize the data shape.
#
# **Step 4:** Print results and interpretation.
